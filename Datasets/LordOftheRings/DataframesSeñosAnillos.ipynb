# %% [markdown]
# #Multiindices

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/LordOftheRings/WordsByCharacter.csv")

# %%
df.head()
# Out:
#                          Film                 Chapter  Character    Race  \
# 0  The Fellowship Of The Ring            01: Prologue      Bilbo  Hobbit
# 1  The Fellowship Of The Ring            01: Prologue     Elrond     Elf
# 2  The Fellowship Of The Ring            01: Prologue  Galadriel     Elf
# 3  The Fellowship Of The Ring            01: Prologue     Gollum  Gollum
# 4  The Fellowship Of The Ring  02: Concerning Hobbits      Bilbo  Hobbit
#
#    Words
# 0      4
# 1      5
# 2    460
# 3     20
# 4    214

# %%
df.index.names # Como se ve antes de configurar los indices.
# Out:
# FrozenList([None])

# %%
multiindex = df.set_index(["Film", "Chapter", "Race", "Character"]).sort_index() #Para modificar el orden de las columnas a nuestro criterio y con el sort ordenar alf.

# %%
multiindex.index.names # Como se ve despues de configurar los indices.
# Out:
# FrozenList(['Film', 'Chapter', 'Race', 'Character'])

# %%
multiindex.head(10) # Ver Cabecera por default son los primeros 5.
# Out:
#                                                                       Words
# Film                       Chapter                Race   Character
# The Fellowship Of The Ring 01: Prologue           Elf    Elrond           5
#                                                          Galadriel      460
#                                                   Gollum Gollum          20
#                                                   Hobbit Bilbo            4
#                            02: Concerning Hobbits Hobbit Bilbo          214
#                            03: The Shire          Ainur  Gandalf        197
#                                                   Hobbit Bilbo           70
#                                                          Frodo          128
#                                                          Hobbit Kids     10
#                                                          Hobbits         12

# %%
multiindex.index.values #Valores luego de modificar los indices, ya no salen en numeros los indices.

# %%
multiindex.loc[("The Fellowship Of The Ring", "01: Prologue"), :]
# Out:
#                   Words
# Race   Character
# Elf    Elrond         5
#        Galadriel    460
# Gollum Gollum        20
# Hobbit Bilbo          4

# %%
multiindex.loc[("The Fellowship Of The Ring", slice(None), "Elf"), :].head(3) #El codigo slice nos trae todas los capitulos "chapter"
# Out:
#                                                                   Words
# Film                       Chapter                Race Character
# The Fellowship Of The Ring 01: Prologue           Elf  Elrond         5
#                                                        Galadriel    460
#                            21: Flight To The Ford Elf  Arwen        131

# %%
multiindex.loc[("The Two Towers", slice(None), slice(None), ["Gandalf", "Saruman"]), :]
# Out:
#                                                                                   Words
# Film           Chapter                                           Race  Character
# The Two Towers 01: The Foundations Of Stone                      Ainur Gandalf       39
#                06: The Burning of the Westfold                   Ainur Saruman      187
#                15: The White Rider                               Ainur Gandalf      298
#                17: The Heir Of Númenor                           Ainur Gandalf      226
#                20: The King Of The Golden Hall                   Ainur Gandalf      151
#                22: Simbelmynë on the Burial Mounds               Ainur Gandalf       28
#                23: The King's Decision                           Ainur Gandalf      165
#                25: The Ring Of Barahir                           Ainur Saruman       68
#                27: Exodus From Edoras                            Ainur Saruman        4
# ...

# %%
multiindex.xs("Isildur", level = "Character")
# Out:
#                                                           Words
# Film                       Chapter                  Race
# The Fellowship Of The Ring 24: The Fate Of The Ring Men       1

# %%
pivoted = df.pivot_table(index = ["Race", "Character"],
                         columns = "Film", 
                         aggfunc = "sum",
                         margins = True,
                         margins_name = "All The Movies",
                         fill_value = 0).sort_index()

pivoted.head(20)
# Out:
# <ipython-input-34-0dd615d866b7>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pivoted = df.pivot_table(index = ["Race", "Character"],
# <ipython-input-34-0dd615d866b7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pivoted = df.pivot_table(index = ["Race", "Character"],
# <ipython-input-34-0dd615d866b7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pivoted = df.pivot_table(index = ["Race", "Character"],
# ...

# %%
order = [("Words","The Fellowship Of The Ring"), 
         ("Words", "The Two Towers"),
         ("Words", "The Return Of The King"),
         ("Words", "All The Movies")]

# %%
pivoted = pivoted.sort_values(by = ("Words", "All The Movies"), ascending= False)

# %%
pivoted = pivoted.reindex(order, axis = 1)

# %%
pivoted
# Out:
#                                                      Words                 \
# Film                            The Fellowship Of The Ring The Two Towers
# Race           Character
# All The Movies                                       11225          11169
# Ainur          Gandalf                                2360            964
# Hobbit         Sam                                     557           1044
# Men            Aragorn                                 920            822
# Hobbit         Frodo                                   967            664
# ...                                                    ...            ...
#                Mrs. Bracegirdle                          2              0
# Orc            Mauhur                                    0              2
# Men            Eothain                                   0              2
# Hobbit         Proudfoot                                 1              0
# ...

# %%
pivoted.loc["Hobbit"]
# Out:
#                                                Words                 \
# Film                      The Fellowship Of The Ring The Two Towers
# Character
# Sam                                              557           1044
# Frodo                                            967            664
# Bilbo                                           1310              0
# Pippin                                           274            359
# Merry                                            323            396
# Hobbits                                           88              0
# Ted                                               55              0
# Gaffer                                            21              0
# Farmer Maggot                                     21              0
# Sandyman                                          17              0
# Deagol                                             0              0
# Hobbit Kids                                       10              0
# ...
