# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/world_population.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.head(5)

# %%
df.index.values

# %%
mfd = pd.melt(df, id_vars=("Continent","Country/Territory","Capital", "2022 Population","Area (km²)" ) ) #Descompone un dataframe segun la columnas que le digamos

# %%
mfd
# Out:
#      Continent  Country/Territory           Capital  2022 Population  \
# 0         Asia        Afghanistan             Kabul         41128771
# 1       Europe            Albania            Tirana          2842321
# 2       Africa            Algeria           Algiers         44903225
# 3      Oceania     American Samoa         Pago Pago            44273
# 4       Europe            Andorra  Andorra la Vella            79824
# ...        ...                ...               ...              ...
# 2803   Oceania  Wallis and Futuna          Mata-Utu            11572
# 2804    Africa     Western Sahara          El Aaiún           575986
# 2805      Asia              Yemen             Sanaa         33696614
# 2806    Africa             Zambia            Lusaka         20017675
# 2807    Africa           Zimbabwe            Harare         16320537
#
#       Area (km²)                     variable False
# 0         652230                         Rank    36
# ...

# %%
mfd.loc[0, "Capital"]
# Out:
# 'Kabul'

# %%
multiindex = mfd.set_index(["Continent", "Country/Territory", "Capital", "Area (km²)", "2022 Population"]).sort_index()

# %%
multiindex
# Out:
#                                                                                        variable  \
# Continent     Country/Territory Capital Area (km²) 2022 Population
# Africa        Algeria           Algiers 2381741    44903225                                Rank
#                                                    44903225                                CCA3
#                                                    44903225                     2020 Population
#                                                    44903225                     2015 Population
#                                                    44903225                     2010 Population
# ...                                                                                         ...
# South America Venezuela         Caracas 916445     28301696                     1980 Population
#                                                    28301696                     1970 Population
# ...

# %%
multiindex.loc[:, ~multiindex.columns.isin(["Rank","World Population Percentage"])] #Ignorar ciertas columnas con "~" si se quita deja las ingresadas
# Out:
#                                                                        CCA3  \
# Continent     Country/Territory Capital     Area (km²) 2022 Population
# Africa        Algeria           Algiers     2381741    44903225         DZA
#               Angola            Luanda      1246700    35588987         AGO
#               Benin             Porto-Novo  112622     13352864         BEN
#               Botswana          Gaborone    582000     2630296          BWA
#               Burkina Faso      Ouagadougou 272967     22673762         BFA
# ...                                                                     ...
# South America Paraguay          Asunción    406752     6780744          PRY
#               Peru              Lima        1285216    34049588         PER
#               Suriname          Paramaribo  163820     618040           SUR
#               Uruguay           Montevideo  181034     3422794          URY
# ...

# %%
tff = multiindex.loc[:, multiindex.columns.isin([])] #Ignorar todas las columnas restantes

# %%
tff
# Out:
# Empty DataFrame
# Columns: []
# ...
